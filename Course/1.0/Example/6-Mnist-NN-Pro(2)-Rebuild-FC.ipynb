# %% [markdown]
# # Minst 手写数字识别
#
# ## 多层神经网络建模与重构全连接层

# %%
import os
from time import time

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_core.examples.tutorials.mnist.input_data as input_data

# %%
# 获取 Mints手写数字数据集
mnist = input_data.read_data_sets("Data/MNIST_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-d559e46e7e8a>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlow10\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlow10\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting Data/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlow10\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting Data/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlow10\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting Data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting Data/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\Anaconda3\envs\TensorFlow10\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## 构建全连接层

# %%
def fcn_layer(
        inputs,  # 输入数据
        input_dim,  # 输入神经元数量
        output_dim,  # 输出神经元数量
        activation=None,  # 激活函数
):
    # 以截断正态分布随机数初始化W
    W = tf.Variable(tf.truncated_normal([input_dim, output_dim], stddev=0.1))

    # 以0初始化b
    b = tf.Variable(tf.zeros([output_dim]))

    # 建立表达式：inputs * W + b
    XWb = tf.matmul(inputs, W) + b

    # 默认不使用激活函数
    if activation is None:
        outputs = XWb
    else:
        # 若传入激活函数，则用其对输出结果进行变换
        outputs = activation(XWb)

    return outputs

# %% [markdown]
# ## 构建输入层（单隐层、多隐层）

# %%
# 定义标签数据占位符
x = tf.placeholder(tf.float32, [None, 784], name="X")
y = tf.placeholder(tf.float32, [None, 10], name="Y")

# TensorBoard：图像数据准备
# 参数代表：
# -1：此处代表未定行数
# 28 与 28，表示28 * 28的图像数据
# 1：表示颜色通道数，1表示单通道无色
image_shaped_input = tf.reshape(x, [-1, 28, 28, 1])

# TensorBoard：输出10张图
tf.summary.image("input", image_shaped_input, 10)
# Out:
# <tf.Tensor 'input:0' shape=() dtype=string>

# %%
H1_NN = 256
H2_NN = 64
H3_NN = 32

# %% [markdown]
# ## 构建隐藏层（单隐层、多隐层）

# %%
# 隐层包含256个神经元
h1 = fcn_layer(inputs=x,
               input_dim=784,
               output_dim=H1_NN,
               activation=tf.nn.relu)

h2 = fcn_layer(inputs=h1,
               input_dim=H1_NN,
               output_dim=H2_NN,
               activation=tf.nn.relu)

h3 = fcn_layer(inputs=h2,
               input_dim=H2_NN,
               output_dim=H3_NN,
               activation=tf.nn.relu)

# %% [markdown]
# ## 构建输出层（单隐层、多隐层）

# %%
forward = fcn_layer(inputs=h3,
                    input_dim=H3_NN,
                    output_dim=10,
                    activation=None)

# %%
pred = tf.nn.softmax(forward)

# %%
# TensorBoard前向输出值以直方图显示
tf.summary.histogram("forward", forward)
# Out:
# <tf.Tensor 'forward:0' shape=() dtype=string>

# %% [markdown]
# ## 定义损失函数

# %%
# 交叉熵
# 采用TF封装好的结合了Softmax的交叉熵函数
# 此处无需人工进行分类，直接传入前向计算结果即可，函数将自动进行Softmax分类
# 此函数将会避免由于人工计算中出现log(0)值导致最终结果为NaN的数据不稳问题
loss_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=forward, labels=y))
# Out:
# WARNING:tensorflow:From <ipython-input-10-a8d1a8870772>:5: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# TensorBoard：将loss损失以标量显示
tf.summary.scalar("loss", loss_function)
# Out:
# <tf.Tensor 'loss:0' shape=() dtype=string>

# %% [markdown]
# ## 设置训练参数

# %%
train_epochs = 40
batch_size = 50
total_batch = int(mnist.train.num_examples / batch_size)
display_step = 1
learning_rate = 0.01

# %% [markdown]
# ## 选择优化器

# %%
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss_function)

# %% [markdown]
# ## 定义准确率

# %%
# 对比预测值与正确值
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(pred, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# TensorBoard：将准确率以标量显示
tf.summary.scalar("Accuracy", accuracy)
# Out:
# <tf.Tensor 'Accuracy:0' shape=() dtype=string>

# %% [markdown]
# ## 保存训练模型
#
# + 防止训练过程被`意外中断`
# + 保存训练结束的模型

# %%
# 存储模型的粒度（此处为每执行完10次保存1次）
# TF中每次保存将会保存5个模型，超过5个模型的将会保存最新模型，并删去旧模型
save_step = 10

ckpt_dir = "Model_ckpt/"

if not os.path.exists(ckpt_dir):
    os.mkdirs(ckpt_dir)

# 训练并保存模型
saver = tf.train.Saver()

# %% [markdown]
# ## 模型训练

# %%
# 准备好会话与变量
startTime = time()

session = tf.Session()
session.run(tf.global_variables_initializer())

# %%
# TensorBoard：合并所有summary
merged_summary_op = tf.summary.merge_all()

# 创建写入符
writer = tf.summary.FileWriter("Log/7-Mnist-NN-Pro-Rebuild-FC", session.graph)

# %%
for epoch in range(train_epochs):
    for batch in range(total_batch):
        # 读取批次数据
        xs, ys = mnist.train.next_batch(batch_size)

        # 执行批次训练
        session.run(optimizer, feed_dict={x: xs, y: ys})

        # 生成每次要写入的Summary信息
        summary_str = session.run(merged_summary_op, feed_dict={x: xs, y: ys})
        # 加入Summary
        writer.add_summary(summary_str, epoch)

    # total_batch个批次使用验证数据计算误差与准确率
    loss, acc = session.run([loss_function, accuracy],
                            feed_dict={x: mnist.validation.images, y: mnist.validation.labels})

    if (epoch + 1) % display_step == 0:
        print("Train epoch: ", "%02d" % (epoch + 1),
              "Loss = ", "{:.9f}".format(loss),
              "Accuracy = ", "{:.4f}".format(acc))

    # 在训练过程中按训练次数保存临时模型副本
    if (epoch + 1) % save_step == 0:
        saver.save(session, os.path.join(ckpt_dir,
                                         "mnist_h256_model_{:06d}.ckpt".format(epoch + 1)))

# 保存训练完成模型
saver.save(session, os.path.join(ckpt_dir, "mnist_h256_model.ckpt"))
print("Model Saved! ")

duration = time() - startTime
print("Total Finished Time: ", "{:.2f}".format(duration))
# Out:
# Train epoch:  01 Loss =  0.160299152 Accuracy =  0.9542
# Train epoch:  02 Loss =  0.161491096 Accuracy =  0.9596
# Train epoch:  03 Loss =  0.129182220 Accuracy =  0.9658
# Train epoch:  04 Loss =  0.143679783 Accuracy =  0.9674
# Train epoch:  05 Loss =  0.153141305 Accuracy =  0.9610
# Train epoch:  06 Loss =  0.183307886 Accuracy =  0.9632
# Train epoch:  07 Loss =  0.142774165 Accuracy =  0.9678
# Train epoch:  08 Loss =  0.158177570 Accuracy =  0.9664
# Train epoch:  09 Loss =  0.181910351 Accuracy =  0.9664
# Train epoch:  10 Loss =  0.131723762 Accuracy =  0.9722
# Train epoch:  11 Loss =  0.166536763 Accuracy =  0.9684
# Train epoch:  12 Loss =  0.169295534 Accuracy =  0.9708
# Train epoch:  13 Loss =  0.169015929 Accuracy =  0.9720
# Train epoch:  14 Loss =  0.181511074 Accuracy =  0.9716
# Train epoch:  15 Loss =  0.149564356 Accuracy =  0.9738
# Train epoch:  16 Loss =  0.151932061 Accuracy =  0.9734
# Train epoch:  17 Loss =  0.242564768 Accuracy =  0.9712
# Train epoch:  18 Loss =  0.160858050 Accuracy =  0.9724
# Train epoch:  19 Loss =  0.209312156 Accuracy =  0.9704
# Train epoch:  20 Loss =  0.173504397 Accuracy =  0.9714
# Train epoch:  21 Loss =  0.168099001 Accuracy =  0.9730
# Train epoch:  22 Loss =  0.176887378 Accuracy =  0.9710
# Train epoch:  23 Loss =  0.201742828 Accuracy =  0.9688
# Train epoch:  24 Loss =  0.222149462 Accuracy =  0.9700
# Train epoch:  25 Loss =  0.187189281 Accuracy =  0.9740
# Train epoch:  26 Loss =  0.204325378 Accuracy =  0.9724
# Train epoch:  27 Loss =  0.203903392 Accuracy =  0.9750
# Train epoch:  28 Loss =  0.185164511 Accuracy =  0.9710
# Train epoch:  29 Loss =  0.200550109 Accuracy =  0.9726
# Train epoch:  30 Loss =  0.226912811 Accuracy =  0.9730
# Train epoch:  31 Loss =  0.176301390 Accuracy =  0.9732
# Train epoch:  32 Loss =  0.254758775 Accuracy =  0.9706
# Train epoch:  33 Loss =  0.186851740 Accuracy =  0.9736
# Train epoch:  34 Loss =  0.209633112 Accuracy =  0.9758
# Train epoch:  35 Loss =  0.170296833 Accuracy =  0.9726
# Train epoch:  36 Loss =  0.285728306 Accuracy =  0.9742
# Train epoch:  37 Loss =  0.245611623 Accuracy =  0.9712
# Train epoch:  38 Loss =  0.294095218 Accuracy =  0.9738
# Train epoch:  39 Loss =  0.179833397 Accuracy =  0.9738
# Train epoch:  40 Loss =  0.233126789 Accuracy =  0.9722
# Model Saved!
# Total Finished Time:  139.03

# %% [markdown]
# ## 读取此前保存的模型

# %%
ckpt = tf.train.get_checkpoint_state(ckpt_dir)

if ckpt and ckpt.model_checkpoint_path:
    # 从已保存的模型中读取参数，还原到当前会话中
    saver.restore(session, ckpt.model_checkpoint_path)

    print("Restore model from: " + ckpt.model_checkpoint_path)
# Out:
# INFO:tensorflow:Restoring parameters from Model_ckpt/mnist_h256_model.ckpt
# Restore model from: Model_ckpt/mnist_h256_model.ckpt

# %% [markdown]
# ## 评估模型（正常训练后所得）

# %%
acc_test = session.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels})

print("Train accuracy: ", acc_test)
# Out:
# Train accuracy:  0.9731

# %% [markdown]
# ## 输出还原模型的准确率（从文件中恢复所得）

# %%
# 不难看出，恢复结果与正常训练结果相当
print("Accuracy: ", accuracy.eval(session=session,
                                  feed_dict={x: mnist.test.images, y: mnist.test.labels}))
# Out:
# Accuracy:  0.9731

# %% [markdown]
# ## 模型运用

# %%
# 由于pred预测解雇是one-hot编码，需要将其转换为0~9的数组
prediction_result = session.run(tf.argmax(pred, 1), feed_dict={x: mnist.test.images})

# %%
# 查看预测结果中的前10项
prediction_result[0:10]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9], dtype=int64)

# %%
## 找出预测错误
compare_lists = prediction_result == np.argmax(mnist.test.labels, 1)

print(compare_lists)
# Out:
# [ True  True  True ...  True  True  True]

# %%
err_list = [i for i in range(len(compare_lists)) if compare_lists[i] == False]
print("Err list length: ", len(err_list), "\n")
print(err_list)
# Out:
# Err list length:  269
#
# [93, 115, 247, 259, 266, 321, 340, 359, 381, 391, 403, 445, 447, 450, 495, 551, 582, 610, 674, 684, 720, 726, 761, 839, 844, 846, 883, 924, 938, 947, 1014, 1039, 1107, 1112, 1181, 1182, 1226, 1242, 1247, 1260, 1319, 1328, 1356, 1393, 1425, 1433, 1444, 1494, 1522, 1530, 1549, 1600, 1678, 1681, 1717, 1751, 1754, 1782, 1800, 1813, 1828, 1850, 1901, 1955, 1969, 2016, 2050, 2053, 2070, 2073, 2093, 2098, 2109, 2118, 2130, 2135, 2182, 2189, 2237, 2272, 2293, 2298, 2329, 2369, 2387, 2406, 2426, 2433, 2447, 2454, 2488, 2534, 2550, 2597, 2598, 2648, 2654, 2770, 2810, 2877, 2896, 2921, 2927, 2939, 2945, 2953, 3030, 3091, 3108, 3240, 3246, 3284, 3289, 3384, 3422, 3451, 3475, 3503, 3520, 3542, 3549, 3558, 3567, 3597, 3662, 3751, 3767, 3776, 3780, 3808, 3811, 3853, 3906, 3941, 3943, 3951, 3976, 3987, 4000, 4065, 4075, 4145, 4163, 4176, 4199, 4205, 4224, 4265, 4289, 4306, 4374, 4399, 4433, 4497, 4536, 4547, 4548, 4571, 4575, 4601, 4635, 4699, 4724, 4731, 4740, 4807, 4808, 4814, 4823, 4860, 4879, 4880, 4890, 4956, 4978, 4990, 5201, 5331, 5457, 5547, 5564, 5573, 5586, 5600, 5634, 5642, 5654, 5676, 5734, 5841, 5877, 5888, 5936, 5955, 5973, 6011, 6023, 6027, 6059, 6145, 6166, 6511, 6532, 6555, 6560, 6576, 6597, 6603, 6625, 6632, 6641, 6651, 6735, 6755, 6783, 7216, 7233, 7338, 7370, 7434, 7473, 7514, 7534, 7603, 7689, 7797, 7821, 7921, 8059, 8065, 8075, 8081, 8094, 8107, 8115, 8246, 8255, 8325, 8453, 8456, 8486, 8527, 8863, 9009, 9015, 9019, 9022, 9024, 9253, 9587, 9634, 9669, 9679, 9692, 9729, 9735, 9741, 9744, 9745, 9749, 9768, 9770, 9782, 9792, 9839, 9856, 9858, 9904, 9982]

# %%
## 定义一个输出错误分类函数
def print_predict_errs(labels, prediction):
    count = 0

    compare_lists = (prediction == np.argmax(labels, 1))
    err_list = [i for i in range(len(compare_lists)) if compare_lists[i] == False]

    for x in err_list:
        print("index: " + str(x) + " 标签值 = ", np.argmax(labels[x]), "预测值 = ", prediction[x])

        count = count + 1

    print("总计: ", count)

# %%
print_predict_errs(labels=mnist.test.images, prediction=prediction_result)
# Out:
# index: 0 标签值 =  355 预测值 =  7
# index: 1 标签值 =  97 预测值 =  2
# index: 2 标签值 =  406 预测值 =  1
# index: 3 标签值 =  262 预测值 =  0
# index: 4 标签值 =  299 预测值 =  4
# index: 5 标签值 =  157 预测值 =  1
# index: 6 标签值 =  287 预测值 =  4
# index: 7 标签值 =  324 预测值 =  9
# index: 8 标签值 =  425 预测值 =  5
# index: 9 标签值 =  357 预测值 =  9
# index: 10 标签值 =  216 预测值 =  0
# index: 11 标签值 =  325 预测值 =  6
# index: 12 标签值 =  211 预测值 =  9
# index: 13 标签值 =  155 预测值 =  0
# index: 14 标签值 =  126 预测值 =  1
# index: 15 标签值 =  624 预测值 =  5
# index: 16 标签值 =  182 预测值 =  9
# index: 17 标签值 =  685 预测值 =  7
# index: 18 标签值 =  257 预测值 =  3
# index: 19 标签值 =  632 预测值 =  4
# index: 20 标签值 =  601 预测值 =  9
# index: 21 标签值 =  374 预测值 =  6
# index: 22 标签值 =  94 预测值 =  6
# index: 23 标签值 =  161 预测值 =  5
# index: 24 标签值 =  399 预测值 =  4
# index: 25 标签值 =  481 预测值 =  0
# index: 26 标签值 =  298 预测值 =  7
# index: 27 标签值 =  604 预测值 =  4
# index: 28 标签值 =  150 预测值 =  0
# index: 29 标签值 =  406 预测值 =  1
# index: 30 标签值 =  232 预测值 =  3
# index: 31 标签值 =  603 预测值 =  1
# index: 32 标签值 =  149 预测值 =  3
# index: 33 标签值 =  490 预测值 =  4
# index: 34 标签值 =  463 预测值 =  7
# index: 35 标签值 =  128 预测值 =  2
# index: 36 标签值 =  208 预测值 =  7
# index: 37 标签值 =  434 预测值 =  1
# index: 38 标签值 =  487 预测值 =  2
# index: 39 标签值 =  657 预测值 =  1
# index: 40 标签值 =  406 预测值 =  1
# index: 41 标签值 =  211 预测值 =  7
# index: 42 标签值 =  177 预测值 =  4
# index: 43 标签值 =  539 预测值 =  2
# index: 44 标签值 =  123 预测值 =  3
# index: 45 标签值 =  655 预测值 =  5
# index: 46 标签值 =  407 预测值 =  1
# index: 47 标签值 =  68 预测值 =  2
# index: 48 标签值 =  465 预测值 =  4
# index: 49 标签值 =  203 预测值 =  4
# index: 50 标签值 =  514 预测值 =  6
# index: 51 标签值 =  441 预测值 =  3
# index: 52 标签值 =  216 预测值 =  5
# index: 53 标签值 =  412 预测值 =  5
# index: 54 标签值 =  286 预测值 =  6
# index: 55 标签值 =  265 预测值 =  0
# index: 56 标签值 =  300 预测值 =  4
# index: 57 标签值 =  156 预测值 =  1
# index: 58 标签值 =  355 预测值 =  9
# index: 59 标签值 =  269 预测值 =  5
# index: 60 标签值 =  200 预测值 =  7
# index: 61 标签值 =  568 预测值 =  8
# index: 62 标签值 =  464 预测值 =  9
# index: 63 标签值 =  242 预测值 =  3
# index: 64 标签值 =  202 预测值 =  7
# index: 65 标签值 =  406 预测值 =  4
# index: 66 标签值 =  351 预测值 =  6
# index: 67 标签值 =  162 预测值 =  4
# index: 68 标签值 =  152 预测值 =  3
# index: 69 标签值 =  453 预测值 =  0
# index: 70 标签值 =  300 预测值 =  7
# index: 71 标签值 =  124 预测值 =  0
# index: 72 标签值 =  127 预测值 =  2
# index: 73 标签值 =  186 预测值 =  9
# index: 74 标签值 =  154 预测值 =  1
# index: 75 标签值 =  293 预测值 =  7
# index: 76 标签值 =  653 预测值 =  3
# index: 77 标签值 =  341 预测值 =  2
# index: 78 标签值 =  185 预测值 =  9
# index: 79 标签值 =  215 预测值 =  7
# index: 80 标签值 =  345 预测值 =  7
# index: 81 标签值 =  235 预测值 =  6
# index: 82 标签值 =  490 预测值 =  2
# index: 83 标签值 =  233 预测值 =  7
# index: 84 标签值 =  189 预测值 =  8
# index: 85 标签值 =  437 预测值 =  4
# index: 86 标签值 =  207 预测值 =  7
# index: 87 标签值 =  150 预测值 =  3
# index: 88 标签值 =  69 预测值 =  6
# index: 89 标签值 =  295 预测值 =  1
# index: 90 标签值 =  155 预测值 =  3
# index: 91 标签值 =  346 预测值 =  6
# index: 92 标签值 =  407 预测值 =  9
# index: 93 标签值 =  181 预测值 =  2
# index: 94 标签值 =  407 预测值 =  1
# index: 95 标签值 =  160 预测值 =  4
# index: 96 标签值 =  434 预测值 =  1
# index: 97 标签值 =  231 预测值 =  7
# index: 98 标签值 =  519 预测值 =  6
# index: 99 标签值 =  181 预测值 =  9
# index: 100 标签值 =  462 预测值 =  6
# index: 101 标签值 =  290 预测值 =  0
# index: 102 标签值 =  233 预测值 =  5
# index: 103 标签值 =  399 预测值 =  4
# index: 104 标签值 =  180 预测值 =  9
# index: 105 标签值 =  235 预测值 =  9
# index: 106 标签值 =  522 预测值 =  2
# index: 107 标签值 =  349 预测值 =  1
# index: 108 标签值 =  183 预测值 =  9
# index: 109 标签值 =  153 预测值 =  4
# index: 110 标签值 =  406 预测值 =  8
# index: 111 标签值 =  628 预测值 =  7
# index: 112 标签值 =  294 预测值 =  3
# index: 113 标签值 =  210 预测值 =  9
# index: 114 标签值 =  629 预测值 =  7
# index: 115 标签值 =  128 预测值 =  9
# index: 116 标签值 =  575 预测值 =  4
# index: 117 标签值 =  245 预测值 =  4
# index: 118 标签值 =  491 预测值 =  9
# index: 119 标签值 =  208 预测值 =  2
# index: 120 标签值 =  154 预测值 =  5
# index: 121 标签值 =  491 预测值 =  4
# index: 122 标签值 =  576 预测值 =  7
# index: 123 标签值 =  354 预测值 =  6
# index: 124 标签值 =  227 预测值 =  7
# index: 125 标签值 =  605 预测值 =  9
# index: 126 标签值 =  211 预测值 =  0
# index: 127 标签值 =  160 预测值 =  5
# index: 128 标签值 =  182 预测值 =  8
# index: 129 标签值 =  576 预测值 =  5
# index: 130 标签值 =  374 预测值 =  6
# index: 131 标签值 =  575 预测值 =  6
# index: 132 标签值 =  129 预测值 =  5
# index: 133 标签值 =  204 预测值 =  7
# index: 134 标签值 =  157 预测值 =  8
# index: 135 标签值 =  573 预测值 =  1
# index: 136 标签值 =  127 预测值 =  0
# index: 137 标签值 =  266 预测值 =  1
# index: 138 标签值 =  207 预测值 =  6
# index: 139 标签值 =  464 预测值 =  4
# index: 211 标签值 =  189 预测值 =  5
# index: 212 标签值 =  664 预测值 =  9
# index: 213 标签值 =  150 预测值 =  3
# index: 214 标签值 =  317 预测值 =  9
# index: 215 标签值 =  344 预测值 =  0
# index: 216 标签值 =  153 预测值 =  3
# index: 217 标签值 =  160 预测值 =  6
# index: 218 标签值 =  246 预测值 =  5
# index: 219 标签值 =  190 预测值 =  5
# index: 220 标签值 =  464 预测值 =  7
# index: 221 标签值 =  569 预测值 =  2
# index: 222 标签值 =  154 预测值 =  2
# index: 223 标签值 =  209 预测值 =  7
# index: 224 标签值 =  296 预测值 =  1
# index: 225 标签值 =  124 预测值 =  2
# index: 226 标签值 =  577 预测值 =  8
# index: 227 标签值 =  181 预测值 =  4
# index: 228 标签值 =  184 预测值 =  1
# index: 229 标签值 =  269 预测值 =  7
# index: 230 标签值 =  548 预测值 =  3
# index: 231 标签值 =  407 预测值 =  3
# index: 232 标签值 =  261 预测值 =  8
# index: 233 标签值 =  183 预测值 =  8
# index: 234 标签值 =  629 预测值 =  7
# index: 235 标签值 =  210 预测值 =  9
# index: 236 标签值 =  93 预测值 =  2
# index: 237 标签值 =  435 预测值 =  2
# index: 238 标签值 =  434 预测值 =  4
# index: 239 标签值 =  575 预测值 =  1
# index: 240 标签值 =  154 预测值 =  5
# index: 241 标签值 =  153 预测值 =  9
# index: 242 标签值 =  184 预测值 =  8
# index: 243 标签值 =  631 预测值 =  7
# index: 244 标签值 =  122 预测值 =  2
# index: 245 标签值 =  238 预测值 =  3
# index: 246 标签值 =  126 预测值 =  0
# index: 247 标签值 =  518 预测值 =  2
# index: 248 标签值 =  289 预测值 =  4
# index: 249 标签值 =  242 预测值 =  2
# index: 250 标签值 =  576 预测值 =  4
# index: 251 标签值 =  181 预测值 =  1
# index: 252 标签值 =  209 预测值 =  9
# index: 253 标签值 =  160 预测值 =  5
# index: 254 标签值 =  353 预测值 =  7
# index: 255 标签值 =  181 预测值 =  7
# index: 256 标签值 =  154 预测值 =  2
# index: 257 标签值 =  407 预测值 =  8
# index: 258 标签值 =  98 预测值 =  2
# index: 259 标签值 =  97 预测值 =  0
# index: 260 标签值 =  189 预测值 =  8
# index: 261 标签值 =  184 预测值 =  5
# index: 262 标签值 =  242 预测值 =  7
# index: 263 标签值 =  260 预测值 =  7
# index: 264 标签值 =  435 预测值 =  9
# index: 265 标签值 =  407 预测值 =  1
# index: 266 标签值 =  575 预测值 =  0
# index: 267 标签值 =  407 预测值 =  1
# index: 268 标签值 =  407 预测值 =  8
# index: 269 标签值 =  576 预测值 =  0
# index: 270 标签值 =  658 预测值 =  3
# index: 271 标签值 =  153 预测值 =  0
# index: 272 标签值 =  182 预测值 =  1
# index: 273 标签值 =  182 预测值 =  9
# index: 274 标签值 =  326 预测值 =  9
# index: 275 标签值 =  179 预测值 =  4
# index: 276 标签值 =  155 预测值 =  1
# index: 277 标签值 =  154 预测值 =  8
# index: 278 标签值 =  126 预测值 =  2
# index: 279 标签值 =  154 预测值 =  1
# index: 280 标签值 =  97 预测值 =  2
# index: 491 标签值 =  438 预测值 =  5
# index: 492 标签值 =  130 预测值 =  2
# index: 493 标签值 =  127 预测值 =  3
# index: 494 标签值 =  202 预测值 =  7
# index: 495 标签值 =  239 预测值 =  2
# index: 496 标签值 =  181 预测值 =  9
# index: 497 标签值 =  433 预测值 =  4
# index: 498 标签值 =  154 预测值 =  0
# index: 499 标签值 =  435 预测值 =  6
# index: 500 标签值 =  153 预测值 =  3
# index: 501 标签值 =  181 预测值 =  9
# index: 502 标签值 =  266 预测值 =  5
# index: 503 标签值 =  122 预测值 =  2
# index: 504 标签值 =  546 预测值 =  1
# index: 505 标签值 =  353 预测值 =  3
# index: 506 标签值 =  213 预测值 =  1
# index: 507 标签值 =  152 预测值 =  3
# index: 508 标签值 =  157 预测值 =  6
# index: 509 标签值 =  159 预测值 =  5
# index: 510 标签值 =  178 预测值 =  7
# index: 511 标签值 =  244 预测值 =  4
# index: 512 标签值 =  380 预测值 =  2
# index: 513 标签值 =  435 预测值 =  2
# index: 514 标签值 =  94 预测值 =  6
# index: 515 标签值 =  434 预测值 =  3
# index: 516 标签值 =  71 预测值 =  2
# index: 517 标签值 =  522 预测值 =  6
# index: 518 标签值 =  567 预测值 =  5
# index: 519 标签值 =  213 预测值 =  4
# index: 520 标签值 =  574 预测值 =  8
# index: 521 标签值 =  604 预测值 =  9
# index: 522 标签值 =  298 预测值 =  7
# index: 523 标签值 =  297 预测值 =  1
# index: 524 标签值 =  121 预测值 =  3
# index: 525 标签值 =  233 预测值 =  0
# index: 526 标签值 =  154 预测值 =  3
# index: 527 标签值 =  124 预测值 =  8
# index: 528 标签值 =  601 预测值 =  3
# index: 529 标签值 =  378 预测值 =  1
# index: 530 标签值 =  182 预测值 =  9
# index: 531 标签值 =  542 预测值 =  3
# index: 532 标签值 =  437 预测值 =  4
# index: 533 标签值 =  462 预测值 =  4
# index: 534 标签值 =  99 预测值 =  6
# index: 535 标签值 =  434 预测值 =  4
# index: 536 标签值 =  379 预测值 =  2
# index: 537 标签值 =  406 预测值 =  1
# index: 538 标签值 =  404 预测值 =  8
# index: 539 标签值 =  100 预测值 =  2
# index: 540 标签值 =  631 预测值 =  5
# index: 541 标签值 =  260 预测值 =  4
# index: 542 标签值 =  154 预测值 =  8
# index: 543 标签值 =  149 预测值 =  8
# index: 544 标签值 =  148 预测值 =  4
# index: 545 标签值 =  159 预测值 =  0
# index: 546 标签值 =  357 预测值 =  0
# index: 547 标签值 =  129 预测值 =  2
# index: 548 标签值 =  406 预测值 =  3
# index: 549 标签值 =  546 预测值 =  2
# index: 550 标签值 =  410 预测值 =  7
# index: 551 标签值 =  149 预测值 =  3
# index: 552 标签值 =  289 预测值 =  0
# index: 553 标签值 =  381 预测值 =  8
# index: 554 标签值 =  216 预测值 =  7
# index: 555 标签值 =  208 预测值 =  4
# index: 556 标签值 =  423 预测值 =  4
# index: 557 标签值 =  180 预测值 =  7
# index: 558 标签值 =  182 预测值 =  9
# index: 559 标签值 =  206 预测值 =  6
# index: 560 标签值 =  210 预测值 =  9
# index: 632 标签值 =  95 预测值 =  2
# index: 633 标签值 =  519 预测值 =  2
# index: 634 标签值 =  208 预测值 =  9
# index: 635 标签值 =  378 预测值 =  2
# index: 636 标签值 =  254 预测值 =  7
# index: 637 标签值 =  440 预测值 =  3
# index: 638 标签值 =  629 预测值 =  5
# index: 639 标签值 =  462 预测值 =  9
# index: 640 标签值 =  434 预测值 =  1
# index: 641 标签值 =  402 预测值 =  8
# index: 642 标签值 =  481 预测值 =  0
# index: 643 标签值 =  407 预测值 =  2
# index: 644 标签值 =  126 预测值 =  0
# index: 645 标签值 =  407 预测值 =  5
# index: 646 标签值 =  98 预测值 =  2
# index: 647 标签值 =  407 预测值 =  1
# index: 648 标签值 =  608 预测值 =  3
# index: 649 标签值 =  206 预测值 =  7
# index: 650 标签值 =  105 预测值 =  6
# index: 651 标签值 =  314 预测值 =  7
# index: 652 标签值 =  603 预测值 =  1
# index: 653 标签值 =  380 预测值 =  2
# index: 654 标签值 =  384 预测值 =  5
# index: 655 标签值 =  149 预测值 =  8
# index: 656 标签值 =  153 预测值 =  0
# index: 657 标签值 =  153 预测值 =  3
# index: 658 标签值 =  215 预测值 =  7
# index: 659 标签值 =  157 预测值 =  2
# index: 660 标签值 =  187 预测值 =  4
# index: 661 标签值 =  156 预测值 =  0
# index: 662 标签值 =  209 预测值 =  9
# index: 663 标签值 =  267 预测值 =  1
# index: 664 标签值 =  130 预测值 =  8
# index: 665 标签值 =  370 预测值 =  6
# index: 666 标签值 =  490 预测值 =  7
# index: 667 标签值 =  181 预测值 =  7
# index: 668 标签值 =  155 预测值 =  4
# index: 669 标签值 =  151 预测值 =  3
# index: 670 标签值 =  380 预测值 =  4
# index: 671 标签值 =  462 预测值 =  9
# index: 672 标签值 =  545 预测值 =  1
# index: 673 标签值 =  187 预测值 =  9
# index: 674 标签值 =  126 预测值 =  3
# index: 675 标签值 =  155 预测值 =  1
# index: 676 标签值 =  204 预测值 =  7
# index: 677 标签值 =  580 预测值 =  3
# index: 678 标签值 =  180 预测值 =  9
# index: 679 标签值 =  181 预测值 =  7
# index: 680 标签值 =  490 预测值 =  6
# index: 681 标签值 =  234 预测值 =  9
# index: 682 标签值 =  210 预测值 =  1
# index: 683 标签值 =  184 预测值 =  3
# index: 684 标签值 =  437 预测值 =  9
# index: 685 标签值 =  217 预测值 =  8
# index: 686 标签值 =  405 预测值 =  3
# index: 687 标签值 =  153 预测值 =  3
# index: 688 标签值 =  129 预测值 =  6
# index: 689 标签值 =  464 预测值 =  7
# index: 690 标签值 =  130 预测值 =  2
# index: 691 标签值 =  434 预测值 =  8
# index: 692 标签值 =  351 预测值 =  5
# index: 693 标签值 =  126 预测值 =  8
# index: 694 标签值 =  434 预测值 =  5
# index: 695 标签值 =  601 预测值 =  1
# index: 696 标签值 =  603 预测值 =  1
# index: 697 标签值 =  235 预测值 =  4
# index: 698 标签值 =  327 预测值 =  4
# index: 699 标签值 =  604 预测值 =  3
# index: 700 标签值 =  151 预测值 =  1
# index: 701 标签值 =  129 预测值 =  0
# index: 772 标签值 =  295 预测值 =  1
# index: 773 标签值 =  210 预测值 =  9
# index: 774 标签值 =  207 预测值 =  4
# index: 775 标签值 =  122 预测值 =  2
# index: 776 标签值 =  377 预测值 =  4
# index: 777 标签值 =  433 预测值 =  1
# index: 778 标签值 =  407 预测值 =  5
# index: 779 标签值 =  181 预测值 =  5
# index: 780 标签值 =  210 预测值 =  3
# index: 781 标签值 =  551 预测值 =  8
# index: 782 标签值 =  267 预测值 =  3
# index: 783 标签值 =  238 预测值 =  1
# index: 784 标签值 =  119 预测值 =  4
# index: 785 标签值 =  376 预测值 =  5
# index: 786 标签值 =  100 预测值 =  6
# index: 787 标签值 =  271 预测值 =  8
# index: 788 标签值 =  183 预测值 =  9
# index: 789 标签值 =  289 预测值 =  4
# index: 790 标签值 =  155 预测值 =  1
# index: 791 标签值 =  189 预测值 =  5
# index: 792 标签值 =  172 预测值 =  3
# index: 793 标签值 =  434 预测值 =  8
# index: 794 标签值 =  495 预测值 =  0
# index: 795 标签值 =  239 预测值 =  3
# index: 796 标签值 =  524 预测值 =  2
# index: 797 标签值 =  187 预测值 =  5
# index: 798 标签值 =  266 预测值 =  1
# index: 799 标签值 =  93 预测值 =  2
# index: 800 标签值 =  241 预测值 =  8
# index: 801 标签值 =  148 预测值 =  3
# index: 802 标签值 =  437 预测值 =  4
# index: 803 标签值 =  428 预测值 =  4
# index: 804 标签值 =  397 预测值 =  0
# index: 805 标签值 =  683 预测值 =  8
# index: 806 标签值 =  126 预测值 =  8
# index: 807 标签值 =  126 预测值 =  3
# index: 808 标签值 =  568 预测值 =  3
# index: 809 标签值 =  601 预测值 =  1
# index: 810 标签值 =  228 预测值 =  7
# index: 811 标签值 =  574 预测值 =  3
# index: 812 标签值 =  569 预测值 =  5
# index: 813 标签值 =  713 预测值 =  9
# index: 814 标签值 =  516 预测值 =  6
# index: 815 标签值 =  123 预测值 =  3
# index: 816 标签值 =  353 预测值 =  2
# index: 817 标签值 =  345 预测值 =  6
# index: 818 标签值 =  127 预测值 =  1
# index: 819 标签值 =  535 预测值 =  3
# index: 820 标签值 =  318 预测值 =  6
# index: 821 标签值 =  155 预测值 =  0
# index: 822 标签值 =  239 预测值 =  7
# index: 823 标签值 =  132 预测值 =  2
# index: 824 标签值 =  406 预测值 =  1
# index: 825 标签值 =  464 预测值 =  7
# index: 826 标签值 =  127 预测值 =  1
# index: 827 标签值 =  408 预测值 =  4
# index: 828 标签值 =  126 预测值 =  2
# index: 829 标签值 =  621 预测值 =  4
# index: 830 标签值 =  432 预测值 =  2
# index: 831 标签值 =  211 预测值 =  1
# index: 832 标签值 =  630 预测值 =  7
# index: 833 标签值 =  213 预测值 =  9
# index: 834 标签值 =  521 预测值 =  6
# index: 835 标签值 =  573 预测值 =  1
# index: 836 标签值 =  128 预测值 =  1
# index: 837 标签值 =  128 预测值 =  2
# index: 838 标签值 =  434 预测值 =  4
# index: 839 标签值 =  348 预测值 =  9
# index: 840 标签值 =  377 预测值 =  1
# index: 841 标签值 =  397 预测值 =  7
# index: 982 标签值 =  153 预测值 =  3
# index: 983 标签值 =  128 预测值 =  8
# index: 984 标签值 =  294 预测值 =  1
# index: 985 标签值 =  132 预测值 =  2
# index: 986 标签值 =  631 预测值 =  6
# index: 987 标签值 =  490 预测值 =  7
# index: 988 标签值 =  434 预测值 =  1
# index: 989 标签值 =  234 预测值 =  6
# index: 990 标签值 =  408 预测值 =  2
# index: 991 标签值 =  180 预测值 =  3
# index: 992 标签值 =  152 预测值 =  9
# index: 993 标签值 =  300 预测值 =  0
# index: 994 标签值 =  348 预测值 =  1
# index: 995 标签值 =  96 预测值 =  2
# index: 996 标签值 =  512 预测值 =  2
# index: 997 标签值 =  262 预测值 =  0
# index: 998 标签值 =  261 预测值 =  8
# index: 999 标签值 =  233 预测值 =  9
# index: 1000 标签值 =  212 预测值 =  9
# index: 1001 标签值 =  127 预测值 =  0
# index: 1002 标签值 =  126 预测值 =  2
# index: 1003 标签值 =  151 预测值 =  5
# index: 1004 标签值 =  152 预测值 =  1
# index: 1005 标签值 =  459 预测值 =  9
# index: 1006 标签值 =  492 预测值 =  7
# index: 1007 标签值 =  154 预测值 =  8
# index: 1008 标签值 =  378 预测值 =  1
# index: 1009 标签值 =  414 预测值 =  0
# index: 1010 标签值 =  178 预测值 =  4
# index: 1011 标签值 =  126 预测值 =  1
# index: 1012 标签值 =  492 预测值 =  7
# index: 1013 标签值 =  318 预测值 =  9
# index: 1014 标签值 =  276 预测值 =  5
# index: 1015 标签值 =  435 预测值 =  4
# index: 1016 标签值 =  101 预测值 =  2
# index: 1017 标签值 =  69 预测值 =  6
# index: 1018 标签值 =  156 预测值 =  8
# index: 1019 标签值 =  572 预测值 =  1
# index: 1020 标签值 =  150 预测值 =  3
# index: 1021 标签值 =  436 预测值 =  7
# index: 1022 标签值 =  188 预测值 =  5
# index: 1023 标签值 =  150 预测值 =  4
# index: 1024 标签值 =  161 预测值 =  4
# index: 1025 标签值 =  129 预测值 =  1
# index: 1026 标签值 =  434 预测值 =  8
# index: 1027 标签值 =  294 预测值 =  1
# index: 1028 标签值 =  240 预测值 =  3
# index: 1029 标签值 =  323 预测值 =  8
# index: 1030 标签值 =  434 预测值 =  1
# index: 1031 标签值 =  537 预测值 =  2
# index: 1032 标签值 =  154 预测值 =  5
# index: 1033 标签值 =  129 预测值 =  8
# index: 1034 标签值 =  159 预测值 =  0
# index: 1035 标签值 =  69 预测值 =  6
# index: 1036 标签值 =  177 预测值 =  2
# index: 1037 标签值 =  572 预测值 =  1
# index: 1038 标签值 =  630 预测值 =  1
# index: 1039 标签值 =  317 预测值 =  1
# index: 1040 标签值 =  126 预测值 =  1
# index: 1041 标签值 =  263 预测值 =  5
# index: 1042 标签值 =  175 预测值 =  3
# index: 1043 标签值 =  288 预测值 =  4
# index: 1044 标签值 =  99 预测值 =  6
# index: 1045 标签值 =  462 预测值 =  9
# index: 1046 标签值 =  290 预测值 =  5
# index: 1047 标签值 =  266 预测值 =  0
# index: 1048 标签值 =  210 预测值 =  9
# index: 1049 标签值 =  465 预测值 =  2
# index: 1050 标签值 =  494 预测值 =  2
# index: 1051 标签值 =  398 预测值 =  4
# index: 1052 标签值 =  185 预测值 =  8
# index: 1053 标签值 =  98 预测值 =  2
# index: 1054 标签值 =  601 预测值 =  1
# index: 1055 标签值 =  316 预测值 =  7
# index: 1056 标签值 =  598 预测值 =  2
# index: 1057 标签值 =  244 预测值 =  4
# index: 1058 标签值 =  209 预测值 =  9
# index: 1059 标签值 =  438 预测值 =  4
# index: 1060 标签值 =  260 预测值 =  4
# index: 1061 标签值 =  553 预测值 =  0
# index: 1062 标签值 =  659 预测值 =  3
# index: 1063 标签值 =  464 预测值 =  9
# index: 1064 标签值 =  154 预测值 =  2
# index: 1065 标签值 =  408 预测值 =  2
# index: 1066 标签值 =  578 预测值 =  3
# index: 1067 标签值 =  155 预测值 =  3
# index: 1068 标签值 =  403 预测值 =  8
# index: 1069 标签值 =  150 预测值 =  3
# index: 1070 标签值 =  377 预测值 =  5
# index: 1071 标签值 =  298 预测值 =  7
# index: 1072 标签值 =  181 预测值 =  3
# index: 1073 标签值 =  286 预测值 =  5
# index: 1074 标签值 =  159 预测值 =  8
# index: 1075 标签值 =  350 预测值 =  1
# index: 1076 标签值 =  229 预测值 =  2
# index: 1077 标签值 =  464 预测值 =  4
# index: 1078 标签值 =  429 预测值 =  4
# index: 1079 标签值 =  379 预测值 =  6
# index: 1080 标签值 =  632 预测值 =  4
# index: 1081 标签值 =  179 预测值 =  9
# index: 1082 标签值 =  237 预测值 =  5
# index: 1083 标签值 =  322 预测值 =  1
# index: 1084 标签值 =  595 预测值 =  0
# index: 1085 标签值 =  497 预测值 =  6
# index: 1086 标签值 =  327 预测值 =  9
# index: 1087 标签值 =  290 预测值 =  5
# index: 1088 标签值 =  352 预测值 =  9
# index: 1089 标签值 =  570 预测值 =  5
# index: 1090 标签值 =  182 预测值 =  9
# index: 1091 标签值 =  182 预测值 =  7
# index: 1092 标签值 =  623 预测值 =  3
# index: 1093 标签值 =  407 预测值 =  8
# index: 1094 标签值 =  125 预测值 =  0
# index: 1095 标签值 =  602 预测值 =  3
# index: 1096 标签值 =  214 预测值 =  7
# index: 1097 标签值 =  573 预测值 =  1
# index: 1098 标签值 =  157 预测值 =  3
# index: 1099 标签值 =  185 预测值 =  6
# index: 1100 标签值 =  490 预测值 =  7
# index: 1101 标签值 =  201 预测值 =  8
# index: 1102 标签值 =  161 预测值 =  5
# index: 1103 标签值 =  233 预测值 =  9
# index: 1104 标签值 =  215 预测值 =  7
# index: 1105 标签值 =  630 预测值 =  9
# index: 1106 标签值 =  95 预测值 =  6
# index: 1107 标签值 =  378 预测值 =  3
# index: 1108 标签值 =  101 预测值 =  6
# index: 1109 标签值 =  174 预测值 =  3
# index: 1110 标签值 =  235 预测值 =  7
# index: 1111 标签值 =  400 预测值 =  4
# index: 1112 标签值 =  128 预测值 =  6
# index: 1113 标签值 =  290 预测值 =  5
# index: 1114 标签值 =  260 预测值 =  3
# index: 1115 标签值 =  434 预测值 =  5
# index: 1116 标签值 =  405 预测值 =  4
# index: 1117 标签值 =  462 预测值 =  7
# index: 1118 标签值 =  126 预测值 =  8
# index: 1119 标签值 =  463 预测值 =  7
# index: 1120 标签值 =  155 预测值 =  8
# index: 1121 标签值 =  100 预测值 =  0
# index: 1122 标签值 =  409 预测值 =  7
# index: 1123 标签值 =  70 预测值 =  6
# index: 1124 标签值 =  182 预测值 =  8
# index: 1125 标签值 =  181 预测值 =  8
# index: 1126 标签值 =  272 预测值 =  7
# index: 1127 标签值 =  177 预测值 =  3
# index: 1128 标签值 =  433 预测值 =  3
# index: 1129 标签值 =  573 预测值 =  1
# index: 1130 标签值 =  438 预测值 =  9
# index: 1131 标签值 =  427 预测值 =  5
# index: 1132 标签值 =  128 预测值 =  2
# index: 1133 标签值 =  183 预测值 =  7
# index: 1134 标签值 =  154 预测值 =  3
# index: 1135 标签值 =  547 预测值 =  5
# index: 1136 标签值 =  600 预测值 =  1
# index: 1137 标签值 =  631 预测值 =  1
# index: 1138 标签值 =  269 预测值 =  2
# index: 1139 标签值 =  127 预测值 =  1
# index: 1140 标签值 =  158 预测值 =  4
# index: 1141 标签值 =  184 预测值 =  7
# index: 1142 标签值 =  153 预测值 =  4
# index: 1143 标签值 =  230 预测值 =  7
# index: 1144 标签值 =  597 预测值 =  5
# index: 1145 标签值 =  214 预测值 =  4
# index: 1146 标签值 =  606 预测值 =  5
# index: 1147 标签值 =  664 预测值 =  4
# index: 1148 标签值 =  262 预测值 =  0
# index: 1149 标签值 =  289 预测值 =  8
# index: 1150 标签值 =  411 预测值 =  3
# index: 1151 标签值 =  101 预测值 =  6
# index: 1152 标签值 =  237 预测值 =  9
# index: 1153 标签值 =  237 预测值 =  6
# index: 1154 标签值 =  157 预测值 =  0
# index: 1155 标签值 =  574 预测值 =  2
# index: 1156 标签值 =  270 预测值 =  7
# index: 1157 标签值 =  184 预测值 =  4
# index: 1158 标签值 =  440 预测值 =  4
# index: 1159 标签值 =  430 预测值 =  4
# index: 1160 标签值 =  382 预测值 =  4
# index: 1161 标签值 =  101 预测值 =  6
# index: 1162 标签值 =  314 预测值 =  6
# index: 1163 标签值 =  601 预测值 =  4
# index: 1164 标签值 =  176 预测值 =  7
# index: 1165 标签值 =  317 预测值 =  9
# index: 1166 标签值 =  262 预测值 =  3
# index: 1167 标签值 =  317 预测值 =  4
# index: 1168 标签值 =  575 预测值 =  5
# index: 1169 标签值 =  184 预测值 =  5
# index: 1170 标签值 =  178 预测值 =  8
# index: 1171 标签值 =  260 预测值 =  7
# index: 1172 标签值 =  126 预测值 =  3
# index: 1173 标签值 =  183 预测值 =  7
# index: 1174 标签值 =  100 预测值 =  2
# index: 1175 标签值 =  212 预测值 =  7
# index: 1176 标签值 =  185 预测值 =  0
# index: 1177 标签值 =  177 预测值 =  2
# index: 1178 标签值 =  213 预测值 =  4
# index: 1179 标签值 =  406 预测值 =  1
# index: 1180 标签值 =  154 预测值 =  1
# index: 1181 标签值 =  378 预测值 =  1
# index: 1182 标签值 =  127 预测值 =  5
# index: 1183 标签值 =  185 预测值 =  9
# index: 1184 标签值 =  130 预测值 =  2
# index: 1185 标签值 =  318 预测值 =  8
# index: 1186 标签值 =  257 预测值 =  7
# index: 1187 标签值 =  103 预测值 =  2
# index: 1188 标签值 =  601 预测值 =  0
# index: 1189 标签值 =  154 预测值 =  1
# index: 1190 标签值 =  159 预测值 =  5
# index: 1191 标签值 =  396 预测值 =  0
# index: 1192 标签值 =  437 预测值 =  9
# index: 1193 标签值 =  546 预测值 =  1
# index: 1194 标签值 =  434 预测值 =  7
# index: 1195 标签值 =  158 预测值 =  0
# index: 1196 标签值 =  239 预测值 =  6
# index: 1197 标签值 =  575 预测值 =  0
# index: 1198 标签值 =  406 预测值 =  8
# index: 1199 标签值 =  71 预测值 =  6
# index: 1200 标签值 =  294 预测值 =  8
# index: 1201 标签值 =  182 预测值 =  1
# index: 1202 标签值 =  233 预测值 =  8
# index: 1203 标签值 =  125 预测值 =  0
# index: 1204 标签值 =  208 预测值 =  3
# index: 1205 标签值 =  125 预测值 =  3
# index: 1206 标签值 =  434 预测值 =  7
# index: 1207 标签值 =  124 预测值 =  2
# index: 1208 标签值 =  632 预测值 =  3
# index: 1209 标签值 =  436 预测值 =  6
# index: 1210 标签值 =  120 预测值 =  2
# index: 1211 标签值 =  435 预测值 =  1
# index: 1212 标签值 =  462 预测值 =  6
# index: 1213 标签值 =  155 预测值 =  1
# index: 1214 标签值 =  377 预测值 =  1
# index: 1215 标签值 =  181 预测值 =  3
# index: 1216 标签值 =  235 预测值 =  7
# index: 1217 标签值 =  573 预测值 =  9
# index: 1218 标签值 =  127 预测值 =  0
# index: 1219 标签值 =  127 预测值 =  8
# index: 1220 标签值 =  659 预测值 =  0
# index: 1221 标签值 =  187 预测值 =  5
# index: 1222 标签值 =  299 预测值 =  4
# index: 1223 标签值 =  125 预测值 =  0
# index: 1224 标签值 =  494 预测值 =  2
# index: 1225 标签值 =  155 预测值 =  8
# index: 1226 标签值 =  121 预测值 =  2
# index: 1227 标签值 =  520 预测值 =  2
# index: 1228 标签值 =  157 预测值 =  9
# index: 1229 标签值 =  434 预测值 =  8
# index: 1230 标签值 =  288 预测值 =  4
# index: 1231 标签值 =  522 预测值 =  0
# index: 1232 标签值 =  154 预测值 =  9
# index: 1233 标签值 =  97 预测值 =  5
# index: 1234 标签值 =  406 预测值 =  8
# index: 1235 标签值 =  128 预测值 =  5
# index: 1236 标签值 =  519 预测值 =  1
# index: 1237 标签值 =  100 预测值 =  2
# index: 1238 标签值 =  574 预测值 =  1
# index: 1239 标签值 =  630 预测值 =  3
# index: 1240 标签值 =  156 预测值 =  1
# index: 1241 标签值 =  462 预测值 =  7
# index: 1242 标签值 =  212 预测值 =  9
# index: 1243 标签值 =  127 预测值 =  5
# index: 1244 标签值 =  183 预测值 =  7
# index: 1245 标签值 =  95 预测值 =  2
# index: 1246 标签值 =  290 预测值 =  0
# index: 1247 标签值 =  569 预测值 =  2
# index: 1248 标签值 =  263 预测值 =  8
# index: 1249 标签值 =  262 预测值 =  8
# index: 1250 标签值 =  600 预测值 =  6
# index: 1251 标签值 =  516 预测值 =  2
# index: 1252 标签值 =  628 预测值 =  5
# index: 1253 标签值 =  486 预测值 =  4
# index: 1254 标签值 =  155 预测值 =  1
# index: 1255 标签值 =  323 预测值 =  9
# index: 1256 标签值 =  155 预测值 =  2
# index: 1257 标签值 =  406 预测值 =  1
# index: 1258 标签值 =  158 预测值 =  5
# index: 1259 标签值 =  665 预测值 =  8
# index: 1260 标签值 =  601 预测值 =  9
# index: 1261 标签值 =  345 预测值 =  0
# index: 1262 标签值 =  96 预测值 =  2
# index: 1263 标签值 =  434 预测值 =  4
# index: 1264 标签值 =  435 预测值 =  4
# index: 1265 标签值 =  150 预测值 =  3
# index: 1266 标签值 =  547 预测值 =  6
# index: 1267 标签值 =  153 预测值 =  8
# index: 1268 标签值 =  604 预测值 =  8
# index: 1269 标签值 =  100 预测值 =  2
# index: 1270 标签值 =  463 预测值 =  4
# index: 1271 标签值 =  630 预测值 =  0
# index: 1272 标签值 =  434 预测值 =  5
# index: 1273 标签值 =  290 预测值 =  0
# index: 1274 标签值 =  436 预测值 =  4
# index: 1275 标签值 =  430 预测值 =  4
# index: 1276 标签值 =  462 预测值 =  7
# index: 1277 标签值 =  631 预测值 =  9
# index: 1278 标签值 =  153 预测值 =  3
# index: 1279 标签值 =  248 预测值 =  4
# index: 1280 标签值 =  267 预测值 =  1
# index: 1281 标签值 =  162 预测值 =  5
# index: 1282 标签值 =  156 预测值 =  9
# index: 1283 标签值 =  434 预测值 =  7
# index: 1284 标签值 =  650 预测值 =  3
# index: 1285 标签值 =  436 预测值 =  5
# index: 1286 标签值 =  407 预测值 =  8
# index: 1287 标签值 =  158 预测值 =  8
# index: 1288 标签值 =  569 预测值 =  0
# index: 1289 标签值 =  458 预测值 =  5
# index: 1290 标签值 =  409 预测值 =  3
# index: 1291 标签值 =  202 预测值 =  3
# index: 1292 标签值 =  573 预测值 =  6
# index: 1293 标签值 =  66 预测值 =  6
# index: 1294 标签值 =  603 预测值 =  0
# index: 1295 标签值 =  295 预测值 =  1
# index: 1296 标签值 =  99 预测值 =  6
# index: 1297 标签值 =  155 预测值 =  0
# index: 1298 标签值 =  267 预测值 =  3
# index: 1299 标签值 =  467 预测值 =  5
# index: 1300 标签值 =  516 预测值 =  4
# index: 1301 标签值 =  434 预测值 =  4
# index: 1302 标签值 =  435 预测值 =  1
# index: 1303 标签值 =  124 预测值 =  2
# index: 1304 标签值 =  182 预测值 =  9
# index: 1305 标签值 =  378 预测值 =  1
# index: 1306 标签值 =  149 预测值 =  4
# index: 1307 标签值 =  515 预测值 =  6
# index: 1308 标签值 =  326 预测值 =  9
# index: 1309 标签值 =  182 预测值 =  9
# index: 1310 标签值 =  183 预测值 =  3
# index: 1311 标签值 =  316 预测值 =  9
# index: 1312 标签值 =  435 预测值 =  8
# index: 1313 标签值 =  437 预测值 =  4
# index: 1314 标签值 =  120 预测值 =  4
# index: 1315 标签值 =  407 预测值 =  3
# index: 1316 标签值 =  545 预测值 =  1
# index: 1317 标签值 =  464 预测值 =  3
# index: 1318 标签值 =  489 预测值 =  1
# index: 1319 标签值 =  177 预测值 =  9
# index: 1320 标签值 =  542 预测值 =  8
# index: 1321 标签值 =  631 预测值 =  7
# index: 1322 标签值 =  574 预测值 =  9
# index: 1323 标签值 =  604 预测值 =  4
# index: 1324 标签值 =  155 预测值 =  8
# index: 1325 标签值 =  132 预测值 =  8
# index: 1326 标签值 =  155 预测值 =  7
# index: 1327 标签值 =  315 预测值 =  9
# index: 1328 标签值 =  346 预测值 =  9
# index: 1329 标签值 =  377 预测值 =  1
# index: 1330 标签值 =  177 预测值 =  4
# index: 1331 标签值 =  290 预测值 =  5
# index: 1332 标签值 =  67 预测值 =  6
# index: 1333 标签值 =  127 预测值 =  0
# index: 1334 标签值 =  630 预测值 =  5
# index: 1335 标签值 =  541 预测值 =  2
# index: 1336 标签值 =  125 预测值 =  2
# index: 1337 标签值 =  548 预测值 =  2
# index: 1338 标签值 =  295 预测值 =  1
# index: 1339 标签值 =  349 预测值 =  5
# index: 1340 标签值 =  154 预测值 =  5
# index: 1341 标签值 =  382 预测值 =  2
# index: 1342 标签值 =  430 预测值 =  4
# index: 1343 标签值 =  181 预测值 =  9
# index: 1344 标签值 =  547 预测值 =  6
# index: 1345 标签值 =  350 预测值 =  2
# index: 1346 标签值 =  271 预测值 =  7
# index: 1347 标签值 =  493 预测值 =  7
# index: 1348 标签值 =  300 预测值 =  2
# index: 1349 标签值 =  129 预测值 =  2
# index: 1350 标签值 =  267 预测值 =  1
# index: 1351 标签值 =  434 预测值 =  1
# index: 1352 标签值 =  122 预测值 =  2
# index: 1353 标签值 =  154 预测值 =  8
# index: 1354 标签值 =  578 预测值 =  3
# index: 1355 标签值 =  326 预测值 =  7
# index: 1356 标签值 =  519 预测值 =  9
# index: 1357 标签值 =  634 预测值 =  4
# index: 1358 标签值 =  127 预测值 =  1
# index: 1359 标签值 =  208 预测值 =  7
# index: 1360 标签值 =  575 预测值 =  1
# index: 1361 标签值 =  490 预测值 =  7
# index: 1362 标签值 =  414 预测值 =  6
# index: 1363 标签值 =  464 预测值 =  7
# index: 1364 标签值 =  377 预测值 =  8
# index: 1365 标签值 =  147 预测值 =  2
# index: 1366 标签值 =  298 预测值 =  7
# index: 1367 标签值 =  406 预测值 =  3
# index: 1368 标签值 =  266 预测值 =  1
# index: 1369 标签值 =  206 预测值 =  7
# index: 1370 标签值 =  291 预测值 =  5
# index: 1371 标签值 =  434 预测值 =  8
# index: 1372 标签值 =  542 预测值 =  2
# index: 1373 标签值 =  542 预测值 =  6
# index: 1374 标签值 =  625 预测值 =  2
# index: 1375 标签值 =  234 预测值 =  2
# index: 1376 标签值 =  379 预测值 =  5
# index: 1377 标签值 =  322 预测值 =  6
# index: 1378 标签值 =  133 预测值 =  5
# index: 1379 标签值 =  289 预测值 =  0
# index: 1380 标签值 =  184 预测值 =  9
# index: 1381 标签值 =  127 预测值 =  2
# index: 1382 标签值 =  382 预测值 =  4
# index: 1383 标签值 =  239 预测值 =  3
# index: 1384 标签值 =  183 预测值 =  3
# index: 1385 标签值 =  210 预测值 =  9
# index: 1386 标签值 =  341 预测值 =  7
# index: 1387 标签值 =  402 预测值 =  6
# index: 1388 标签值 =  103 预测值 =  6
# index: 1389 标签值 =  436 预测值 =  8
# index: 1390 标签值 =  261 预测值 =  0
# index: 1391 标签值 =  147 预测值 =  4
# index: 1392 标签值 =  155 预测值 =  1
# index: 1393 标签值 =  90 预测值 =  2
# index: 1394 标签值 =  439 预测值 =  8
# index: 1395 标签值 =  128 预测值 =  2
# index: 1396 标签值 =  490 预测值 =  9
# index: 1397 标签值 =  182 预测值 =  1
# index: 1398 标签值 =  260 预测值 =  8
# index: 1399 标签值 =  384 预测值 =  0
# index: 1400 标签值 =  545 预测值 =  6
# index: 1401 标签值 =  658 预测值 =  7
# index: 1402 标签值 =  210 预测值 =  2
# index: 1403 标签值 =  543 预测值 =  1
# index: 1404 标签值 =  155 预测值 =  0
# index: 1405 标签值 =  264 预测值 =  5
# index: 1406 标签值 =  239 预测值 =  5
# index: 1407 标签值 =  381 预测值 =  2
# index: 1408 标签值 =  294 预测值 =  0
# index: 1409 标签值 =  408 预测值 =  2
# index: 1410 标签值 =  525 预测值 =  2
# index: 1411 标签值 =  180 预测值 =  0
# index: 1412 标签值 =  127 预测值 =  2
# index: 1413 标签值 =  289 预测值 =  4
# index: 1414 标签值 =  266 预测值 =  9
# index: 1415 标签值 =  155 预测值 =  8
# index: 1416 标签值 =  127 预测值 =  0
# index: 1417 标签值 =  465 预测值 =  9
# index: 1418 标签值 =  427 预测值 =  9
# index: 1419 标签值 =  462 预测值 =  4
# index: 1420 标签值 =  351 预测值 =  6
# index: 1421 标签值 =  318 预测值 =  5
# index: 1422 标签值 =  158 预测值 =  4
# index: 1423 标签值 =  575 预测值 =  9
# index: 1424 标签值 =  685 预测值 =  1
# index: 1425 标签值 =  156 预测值 =  9
# index: 1426 标签值 =  154 预测值 =  3
# index: 1427 标签值 =  313 预测值 =  4
# index: 1428 标签值 =  179 预测值 =  9
# index: 1429 标签值 =  180 预测值 =  9
# index: 1430 标签值 =  547 预测值 =  1
# index: 1431 标签值 =  149 预测值 =  2
# index: 1432 标签值 =  605 预测值 =  2
# index: 1433 标签值 =  151 预测值 =  9
# index: 1434 标签值 =  433 预测值 =  1
# index: 1435 标签值 =  462 预测值 =  9
# index: 1436 标签值 =  267 预测值 =  6
# index: 1437 标签值 =  203 预测值 =  4
# index: 1438 标签值 =  411 预测值 =  0
# index: 1439 标签值 =  463 预测值 =  9
# index: 1440 标签值 =  456 预测值 =  4
# index: 1441 标签值 =  489 预测值 =  8
# index: 1442 标签值 =  401 预测值 =  3
# index: 1443 标签值 =  379 预测值 =  8
# index: 1444 标签值 =  92 预测值 =  9
# index: 1445 标签值 =  125 预测值 =  0
# index: 1446 标签值 =  127 预测值 =  2
# index: 1447 标签值 =  163 预测值 =  5
# index: 1448 标签值 =  295 预测值 =  1
# index: 1449 标签值 =  315 预测值 =  9
# index: 1450 标签值 =  541 预测值 =  6
# index: 1451 标签值 =  518 预测值 =  2
# index: 1452 标签值 =  714 预测值 =  9
# index: 1453 标签值 =  433 预测值 =  4
# index: 1454 标签值 =  429 预测值 =  0
# index: 1455 标签值 =  213 预测值 =  9
# index: 1456 标签值 =  357 预测值 =  6
# index: 1457 标签值 =  152 预测值 =  0
# index: 1458 标签值 =  519 预测值 =  6
# index: 1459 标签值 =  266 预测值 =  2
# index: 1460 标签值 =  161 预测值 =  5
# index: 1461 标签值 =  430 预测值 =  4
# index: 1462 标签值 =  127 预测值 =  2
# index: 1463 标签值 =  181 预测值 =  3
# index: 1464 标签值 =  439 预测值 =  8
# index: 1465 标签值 =  683 预测值 =  4
# index: 1466 标签值 =  260 预测值 =  5
# index: 1467 标签值 =  400 预测值 =  5
# index: 1468 标签值 =  368 预测值 =  0
# index: 1469 标签值 =  522 预测值 =  3
# index: 1470 标签值 =  272 预测值 =  8
# index: 1471 标签值 =  464 预测值 =  5
# index: 1472 标签值 =  294 预测值 =  3
# index: 1473 标签值 =  319 预测值 =  5
# index: 1474 标签值 =  154 预测值 =  8
# index: 1475 标签值 =  574 预测值 =  6
# index: 1476 标签值 =  411 预测值 =  5
# index: 1477 标签值 =  206 预测值 =  7
# index: 1478 标签值 =  376 预测值 =  6
# index: 1479 标签值 =  350 预测值 =  3
# index: 1480 标签值 =  152 预测值 =  3
# index: 1481 标签值 =  209 预测值 =  9
# index: 1482 标签值 =  206 预测值 =  6
# index: 1483 标签值 =  434 预测值 =  1
# index: 1484 标签值 =  406 预测值 =  1
# index: 1485 标签值 =  240 预测值 =  2
# index: 1486 标签值 =  459 预测值 =  9
# index: 1487 标签值 =  128 预测值 =  0
# index: 1488 标签值 =  341 预测值 =  4
# index: 1489 标签值 =  631 预测值 =  3
# index: 1490 标签值 =  127 预测值 =  3
# index: 1491 标签值 =  97 预测值 =  6
# index: 1492 标签值 =  206 预测值 =  9
# index: 1493 标签值 =  605 预测值 =  5
# index: 1494 标签值 =  206 预测值 =  0
# index: 1495 标签值 =  96 预测值 =  3
# index: 1496 标签值 =  316 预测值 =  7
# index: 1497 标签值 =  493 预测值 =  7
# index: 1498 标签值 =  272 预测值 =  7
# index: 1499 标签值 =  150 预测值 =  8
# index: 1500 标签值 =  151 预测值 =  7
# index: 1501 标签值 =  183 预测值 =  9
# index: 1502 标签值 =  631 预测值 =  8
# index: 1503 标签值 =  124 预测值 =  3
# index: 1504 标签值 =  150 预测值 =  0
# index: 1505 标签值 =  601 预测值 =  7
# index: 1506 标签值 =  129 预测值 =  2
# index: 1507 标签值 =  184 预测值 =  7
# index: 1508 标签值 =  289 预测值 =  9
# index: 1509 标签值 =  377 预测值 =  4
# index: 1510 标签值 =  289 预测值 =  5
# index: 1511 标签值 =  574 预测值 =  4
# index: 1512 标签值 =  324 预测值 =  9
# index: 1513 标签值 =  348 预测值 =  3
# index: 1514 标签值 =  153 预测值 =  2
# index: 1515 标签值 =  155 预测值 =  1
# index: 1516 标签值 =  462 预测值 =  4
# index: 1517 标签值 =  413 预测值 =  0
# index: 1518 标签值 =  268 预测值 =  2
# index: 1519 标签值 =  152 预测值 =  3
# index: 9551 标签值 =  160 预测值 =  4
# index: 9552 标签值 =  127 预测值 =  0
# index: 9553 标签值 =  407 预测值 =  9
# index: 9554 标签值 =  297 预测值 =  9
# index: 9555 标签值 =  547 预测值 =  6
# index: 9556 标签值 =  131 预测值 =  1
# index: 9557 标签值 =  155 预测值 =  8
# index: 9558 标签值 =  630 预测值 =  3
# index: 9559 标签值 =  154 预测值 =  3
# index: 9560 标签值 =  187 预测值 =  7
# index: 9561 标签值 =  155 预测值 =  3
# index: 9562 标签值 =  185 预测值 =  9
# index: 9563 标签值 =  184 预测值 =  8
# index: 9564 标签值 =  594 预测值 =  8
# index: 9565 标签值 =  151 预测值 =  4
# index: 9566 标签值 =  215 预测值 =  7
# index: 9567 标签值 =  685 预测值 =  7
# index: 9568 标签值 =  70 预测值 =  6
# index: 9569 标签值 =  406 预测值 =  2
# index: 9570 标签值 =  379 预测值 =  1
# index: 9571 标签值 =  405 预测值 =  9
# index: 9572 标签值 =  153 预测值 =  8
# index: 9573 标签值 =  436 预测值 =  7
# index: 9574 标签值 =  157 预测值 =  8
# index: 9575 标签值 =  128 预测值 =  8
# index: 9576 标签值 =  490 预测值 =  7
# index: 9577 标签值 =  272 预测值 =  2
# index: 9578 标签值 =  410 预测值 =  2
# index: 9579 标签值 =  439 预测值 =  3
# index: 9580 标签值 =  463 预测值 =  9
# index: 9581 标签值 =  149 预测值 =  3
# index: 9582 标签值 =  123 预测值 =  3
# index: 9583 标签值 =  435 预测值 =  5
# index: 9584 标签值 =  268 预测值 =  5
# index: 9585 标签值 =  128 预测值 =  0
# index: 9586 标签值 =  175 预测值 =  7
# index: 9587 标签值 =  119 预测值 =  4
# index: 9588 标签值 =  519 预测值 =  5
# index: 9589 标签值 =  71 预测值 =  6
# index: 9590 标签值 =  188 预测值 =  5
# index: 9591 标签值 =  131 预测值 =  1
# index: 9592 标签值 =  152 预测值 =  4
# index: 9593 标签值 =  130 预测值 =  1
# index: 9594 标签值 =  407 预测值 =  1
# index: 9595 标签值 =  286 预测值 =  2
# index: 9596 标签值 =  183 预测值 =  8
# index: 9597 标签值 =  96 预测值 =  2
# index: 9598 标签值 =  70 预测值 =  6
# index: 9599 标签值 =  129 预测值 =  1
# index: 9600 标签值 =  320 预测值 =  5
# index: 9601 标签值 =  129 预测值 =  0
# index: 9602 标签值 =  543 预测值 =  1
# index: 9603 标签值 =  566 预测值 =  2
# index: 9604 标签值 =  348 预测值 =  3
# index: 9605 标签值 =  401 预测值 =  4
# index: 9606 标签值 =  518 预测值 =  5
# index: 9607 标签值 =  519 预测值 =  6
# index: 9608 标签值 =  273 预测值 =  7
# index: 9609 标签值 =  435 预测值 =  8
# index: 9610 标签值 =  208 预测值 =  9
# index: 9611 标签值 =  564 预测值 =  0
# index: 9612 标签值 =  186 预测值 =  1
# index: 9613 标签值 =  131 预测值 =  2
# index: 9614 标签值 =  536 预测值 =  3
# index: 9615 标签值 =  630 预测值 =  4
# index: 9616 标签值 =  598 预测值 =  5
# index: 9617 标签值 =  101 预测值 =  6
# index: 9753 标签值 =  412 预测值 =  0
# index: 9754 标签值 =  268 预测值 =  5
# index: 9755 标签值 =  374 预测值 =  8
# index: 9756 标签值 =  104 预测值 =  6
# index: 9757 标签值 =  129 预测值 =  0
# index: 9758 标签值 =  411 预测值 =  3
# index: 9759 标签值 =  158 预测值 =  8
# index: 9760 标签值 =  268 预测值 =  1
# index: 9761 标签值 =  132 预测值 =  0
# index: 9762 标签值 =  323 预测值 =  3
# index: 9763 标签值 =  160 预测值 =  0
# index: 9764 标签值 =  243 预测值 =  4
# index: 9765 标签值 =  239 预测值 =  7
# index: 9766 标签值 =  430 预测值 =  4
# index: 9767 标签值 =  216 预测值 =  9
# index: 9768 标签值 =  155 预测值 =  0
# index: 9769 标签值 =  184 预测值 =  9
# index: 9770 标签值 =  481 预测值 =  0
# index: 9771 标签值 =  346 预测值 =  7
# index: 9772 标签值 =  352 预测值 =  1
# index: 9773 标签值 =  319 预测值 =  7
# index: 9774 标签值 =  133 预测值 =  1
# index: 9775 标签值 =  103 预测值 =  6
# index: 9776 标签值 =  158 预测值 =  6
# index: 9777 标签值 =  241 预测值 =  5
# index: 9778 标签值 =  103 预测值 =  6
# index: 9779 标签值 =  158 预测值 =  2
# index: 9780 标签值 =  324 预测值 =  8
# index: 9781 标签值 =  273 预测值 =  7
# index: 9782 标签值 =  510 预测值 =  9
# index: 9783 标签值 =  189 预测值 =  4
# index: 9784 标签值 =  213 预测值 =  9
# index: 9785 标签值 =  185 预测值 =  9
# index: 9786 标签值 =  598 预测值 =  5
# index: 9787 标签值 =  375 预测值 =  3
# index: 9788 标签值 =  238 预测值 =  7
# index: 9789 标签值 =  188 预测值 =  4
# index: 9790 标签值 =  126 预测值 =  3
# index: 9791 标签值 =  131 预测值 =  0
# index: 9792 标签值 =  188 预测值 =  9
# index: 9793 标签值 =  521 预测值 =  6
# index: 9794 标签值 =  385 预测值 =  6
# index: 9795 标签值 =  432 预测值 =  1
# index: 9796 标签值 =  406 预测值 =  1
# index: 9797 标签值 =  128 预测值 =  3
# index: 9798 标签值 =  535 预测值 =  2
# index: 9799 标签值 =  161 预测值 =  1
# index: 9800 标签值 =  518 预测值 =  0
# index: 9801 标签值 =  157 预测值 =  0
# index: 9802 标签值 =  159 预测值 =  1
# index: 9803 标签值 =  244 预测值 =  2
# index: 9804 标签值 =  129 预测值 =  3
# index: 9805 标签值 =  290 预测值 =  4
# index: 9806 标签值 =  210 预测值 =  7
# index: 9807 标签值 =  436 预测值 =  8
# index: 9808 标签值 =  244 预测值 =  9
# index: 9809 标签值 =  411 预测值 =  0
# index: 9810 标签值 =  435 预测值 =  1
# index: 9811 标签值 =  654 预测值 =  2
# index: 9812 标签值 =  410 预测值 =  3
# index: 9813 标签值 =  161 预测值 =  4
# index: 9814 标签值 =  434 预测值 =  5
# index: 9815 标签值 =  379 预测值 =  6
# index: 9816 标签值 =  574 预测值 =  7
# index: 9817 标签值 =  132 预测值 =  8
# index: 9818 标签值 =  161 预测值 =  0
# index: 9819 标签值 =  434 预测值 =  1
# index: 9820 标签值 =  569 预测值 =  2
# index: 9821 标签值 =  126 预测值 =  3
# index: 9822 标签值 =  435 预测值 =  4
# index: 9823 标签值 =  210 预测值 =  7
# index: 9824 标签值 =  291 预测值 =  8
# index: 9825 标签值 =  212 预测值 =  9
# index: 9826 标签值 =  404 预测值 =  0
# index: 9827 标签值 =  157 预测值 =  8
# index: 9828 标签值 =  155 预测值 =  3
# index: 9829 标签值 =  461 预测值 =  9
# index: 9830 标签值 =  162 预测值 =  5
# index: 9831 标签值 =  132 预测值 =  5
# index: 9832 标签值 =  129 预测值 =  2
# index: 9833 标签值 =  128 预测值 =  6
# index: 9834 标签值 =  157 预测值 =  8
# index: 9835 标签值 =  436 预测值 =  4
# index: 9836 标签值 =  158 预测值 =  1
# index: 9837 标签值 =  208 预测值 =  7
# index: 9838 标签值 =  157 预测值 =  1
# index: 9839 标签值 =  184 预测值 =  9
# index: 9840 标签值 =  128 预测值 =  3
# index: 9841 标签值 =  627 预测值 =  5
# index: 9842 标签值 =  486 预测值 =  6
# index: 9843 标签值 =  215 预测值 =  9
# index: 9844 标签值 =  433 预测值 =  1
# index: 9845 标签值 =  297 预测值 =  1
# index: 9846 标签值 =  158 预测值 =  1
# index: 9847 标签值 =  630 预测值 =  2
# index: 9848 标签值 =  158 预测值 =  1
# index: 9849 标签值 =  127 预测值 =  2
# index: 9850 标签值 =  413 预测值 =  0
# index: 9851 标签值 =  685 预测值 =  7
# index: 9852 标签值 =  214 预测值 =  7
# index: 9853 标签值 =  575 预测值 =  5
# index: 9854 标签值 =  158 预测值 =  8
# index: 9855 标签值 =  154 预测值 =  2
# index: 9856 标签值 =  347 预测值 =  5
# index: 9857 标签值 =  291 预测值 =  8
# index: 9858 标签值 =  267 预测值 =  8
# index: 9859 标签值 =  657 预测值 =  7
# index: 9860 标签值 =  127 预测值 =  3
# index: 9861 标签值 =  190 预测值 =  4
# index: 9862 标签值 =  103 预测值 =  6
# index: 9863 标签值 =  131 预测值 =  8
# index: 9864 标签值 =  656 预测值 =  7
# index: 9865 标签值 =  439 预测值 =  0
# index: 9866 标签值 =  519 预测值 =  4
# index: 9867 标签值 =  436 预测值 =  2
# index: 9868 标签值 =  214 预测值 =  7
# index: 9869 标签值 =  215 预测值 =  7
# index: 9870 标签值 =  161 预测值 =  5
# index: 9871 标签值 =  491 预测值 =  4
# index: 9872 标签值 =  568 预测值 =  3
# index: 9873 标签值 =  217 预测值 =  4
# index: 9874 标签值 =  434 预测值 =  2
# index: 9875 标签值 =  435 预测值 =  8
# index: 9876 标签值 =  570 预测值 =  1
# index: 9877 标签值 =  217 预测值 =  5
# index: 9878 标签值 =  159 预测值 =  1
# index: 9879 标签值 =  403 预测值 =  0
# index: 9880 标签值 =  128 预测值 =  2
# index: 9881 标签值 =  180 预测值 =  3
# index: 9882 标签值 =  155 预测值 =  3
# index: 9883 标签值 =  239 预测值 =  5
# index: 9884 标签值 =  320 预测值 =  7
# index: 9885 标签值 =  374 预测值 =  0
# index: 9886 标签值 =  238 预测值 =  6
# index: 9887 标签值 =  160 预测值 =  8
# index: 9888 标签值 =  575 预测值 =  6
# index: 9889 标签值 =  125 预测值 =  3
# index: 9890 标签值 =  188 预测值 =  9
# index: 9891 标签值 =  240 预测值 =  9
# index: 9892 标签值 =  132 预测值 =  8
# index: 9893 标签值 =  603 预测值 =  2
# index: 9894 标签值 =  490 预测值 =  7
# index: 9895 标签值 =  215 预测值 =  7
# index: 9896 标签值 =  406 预测值 =  1
# index: 9897 标签值 =  274 预测值 =  0
# index: 9898 标签值 =  241 预测值 =  1
# index: 9899 标签值 =  436 预测值 =  7
# index: 9900 标签值 =  569 预测值 =  8
# index: 9901 标签值 =  159 预测值 =  9
# index: 9902 标签值 =  546 预测值 =  0
# index: 9903 标签值 =  379 预测值 =  1
# index: 9904 标签值 =  266 预测值 =  9
# index: 9905 标签值 =  328 预测值 =  3
# index: 9906 标签值 =  457 预测值 =  4
# index: 9907 标签值 =  271 预测值 =  5
# index: 9908 标签值 =  76 预测值 =  6
# index: 9909 标签值 =  491 预测值 =  7
# index: 9910 标签值 =  192 预测值 =  8
# index: 9911 标签值 =  508 预测值 =  0
# index: 9912 标签值 =  406 预测值 =  1
# index: 9913 标签值 =  218 预测值 =  2
# index: 9914 标签值 =  602 预测值 =  3
# index: 9915 标签值 =  407 预测值 =  4
# index: 9916 标签值 =  342 预测值 =  7
# index: 9917 标签值 =  157 预测值 =  8
# index: 9918 标签值 =  188 预测值 =  9
# index: 9919 标签值 =  212 预测值 =  7
# index: 9920 标签值 =  575 预测值 =  8
# index: 9921 标签值 =  210 预测值 =  6
# index: 9922 标签值 =  374 预测值 =  4
# index: 9923 标签值 =  241 预测值 =  1
# index: 9924 标签值 =  329 预测值 =  9
# index: 9925 标签值 =  594 预测值 =  3
# index: 9926 标签值 =  273 预测值 =  8
# index: 9927 标签值 =  453 预测值 =  4
# index: 9928 标签值 =  163 预测值 =  4
# index: 9929 标签值 =  210 预测值 =  7
# index: 9930 标签值 =  128 预测值 =  0
# index: 9931 标签值 =  572 预测值 =  1
# index: 9932 标签值 =  462 预测值 =  9
# index: 9933 标签值 =  405 预测值 =  2
# index: 9934 标签值 =  156 预测值 =  8
# index: 9935 标签值 =  212 预测值 =  7
# index: 9936 标签值 =  184 预测值 =  8
# index: 9937 标签值 =  130 预测值 =  2
# index: 9938 标签值 =  104 预测值 =  6
# index: 9939 标签值 =  494 预测值 =  0
# index: 9940 标签值 =  127 预测值 =  6
# index: 9941 标签值 =  351 预测值 =  5
# index: 9942 标签值 =  160 预测值 =  3
# index: 9943 标签值 =  160 预测值 =  3
# index: 9944 标签值 =  245 预测值 =  3
# index: 9945 标签值 =  317 预测值 =  9
# index: 9946 标签值 =  434 预测值 =  1
# index: 9947 标签值 =  317 预测值 =  4
# index: 9948 标签值 =  127 预测值 =  0
# index: 9949 标签值 =  598 预测值 =  6
# index: 9950 标签值 =  570 预测值 =  1
# index: 9951 标签值 =  160 预测值 =  0
# index: 9952 标签值 =  565 预测值 =  0
# index: 9953 标签值 =  625 预测值 =  6
# index: 9954 标签值 =  183 预测值 =  2
# index: 9955 标签值 =  133 预测值 =  1
# index: 9956 标签值 =  406 预测值 =  1
# index: 9957 标签值 =  212 预测值 =  7
# index: 9958 标签值 =  463 预测值 =  7
# index: 9959 标签值 =  575 预测值 =  8
# index: 9960 标签值 =  187 预测值 =  4
# index: 9961 标签值 =  547 预测值 =  6
# index: 9962 标签值 =  157 预测值 =  0
# index: 9963 标签值 =  261 预测值 =  7
# index: 9964 标签值 =  413 预测值 =  0
# index: 9965 标签值 =  154 预测值 =  3
# index: 9966 标签值 =  491 预测值 =  6
# index: 9967 标签值 =  157 预测值 =  8
# index: 9968 标签值 =  216 预测值 =  7
# index: 9969 标签值 =  626 预测值 =  1
# index: 9970 标签值 =  539 预测值 =  5
# index: 9971 标签值 =  185 预测值 =  2
# index: 9972 标签值 =  602 预测值 =  4
# index: 9973 标签值 =  188 预测值 =  9
# index: 9974 标签值 =  491 预测值 =  4
# index: 9975 标签值 =  182 预测值 =  3
# index: 9976 标签值 =  462 预测值 =  6
# index: 9977 标签值 =  160 预测值 =  4
# index: 9978 标签值 =  160 预测值 =  1
# index: 9979 标签值 =  491 预测值 =  7
# index: 9980 标签值 =  440 预测值 =  2
# index: 9981 标签值 =  103 预测值 =  6
# index: 9982 标签值 =  100 预测值 =  3
# index: 9983 标签值 =  155 预测值 =  0
# index: 9984 标签值 =  489 预测值 =  1
# index: 9985 标签值 =  155 预测值 =  2
# index: 9986 标签值 =  154 预测值 =  3
# index: 9987 标签值 =  290 预测值 =  4
# index: 9988 标签值 =  602 预测值 =  5
# index: 9989 标签值 =  102 预测值 =  6
# index: 9990 标签值 =  184 预测值 =  7
# index: 9991 标签值 =  152 预测值 =  8
# index: 9992 标签值 =  187 预测值 =  9
# index: 9993 标签值 =  377 预测值 =  0
# index: 9994 标签值 =  128 预测值 =  1
# index: 9995 标签值 =  125 预测值 =  2
# index: 9996 标签值 =  151 预测值 =  3
# index: 9997 标签值 =  711 预测值 =  4
# index: 9998 标签值 =  464 预测值 =  5
# index: 9999 标签值 =  75 预测值 =  6
# 总计:  10000

# %% [markdown]
# ## 模型可视化

# %%
# 定义可视化函数
def plot_images_labels_prediction(
        images,  # 图像列表
        labels,  # 标签列表
        prediction,  # 预测值列表（若传入空表则为展示数据集中image与对应标签）
        index,  # 从第index个开始显示
        num=10,  # 缺省一次显示10幅
):
    # 获取当前图表
    flg = plt.gcf()

    # 1英寸等于2.54cm
    flg.set_size_inches(10, 12)

    # 最多展示25个要处理的子图
    if num > 25:
        num = 25

    for i in range(0, num):
        # 获取当前要处理的子图
        ax = plt.subplot(5, 5, i + 1)

        # 显示第index个图像
        ax.imshow(np.reshape(images[index], (28, 28), ), cmap="binary")

        # 构建该图上要显示的title信息
        title = "Label = " + str(np.argmax(labels[index]))

        if len(prediction) > 0:
            title += ", Pred = " + str(prediction[index])

        ax.set_title(title, fontsize=10)

        index += 1

    plt.show()

# %%
plot_images_labels_prediction(
    mnist.test.images,
    mnist.test.labels,
    prediction_result,
    355,
    20
)
